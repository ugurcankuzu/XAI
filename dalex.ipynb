# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurcankuzu/XAI/blob/main/dalex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dalex
import dalex as dx
from shapash import SmartExplainer
import pickle

# %%
with open("datasetAndModelOut.pkl","rb") as f:
  lr = pickle.load(f)
  testX = pickle.load(f)
  trainX = pickle.load(f)
  testY = pickle.load(f)
  trainY = pickle.load(f)

# %%
dalexp = dx.Explainer(lr,testX,testY)
# Out:
# Preparation of a new explainer is initiated
#
#   -> data              : 61 rows 7 cols
#   -> target variable   : Parameter 'y' was a pandas.Series. Converted to a numpy.ndarray.
#   -> target variable   : 61 values
#   -> model_class       : sklearn.linear_model._base.LinearRegression (default)
#   -> label             : Not specified, model's class short name will be used. (default)
#   -> predict function  : <function yhat_default at 0x7fd61471faf0> will be used (default)
#   -> predict function  : Accepts pandas.DataFrame and numpy.ndarray.
#   -> predicted values  : min = -1.02, mean = 5.51, max = 19.9
#   -> model type        : regression will be used (default)
#   -> residual function : difference between y and yhat (default)
#   -> residuals         : min = -3.28, mean = -0.187, max = 6.5
#   -> model_info        : package sklearn
#
# A new explainer has been created!
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning:
#
# ...

# %%
pred = dalexp.predict(testX)

# %%
dalexp.predict_parts(testX.iloc[1],type="shap").plot()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
testY.iloc[1]
# Out:
# 5.25

# %%
dalexp.predict_profile(testX.iloc[1]).plot(dalexp.predict_profile(testX.iloc[2]))
# Out:
# ...
# Calculating ceteris paribus: 100%|██████████| 7/7 [00:00<00:00, 298.08it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dalexp.model_performance('regression').plot()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dalexp.model_parts(type="variable_importance").plot()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
